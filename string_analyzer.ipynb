# %%
sentence="Learning Python is amazing and fun"
print(len(sentence))
print(sentence.count("a"))
updated=sentence.replace("Python","Coding")
print("updated sentence is :",updated)
word=sentence.split(" ")
print("Word :",word)
print(word[2])
# Out:
# 34
# 4
# updated sentence is : Learning Coding is amazing and fun
# Word : ['Learning', 'Python', 'is', 'amazing', 'and', 'fun']
# is
